# %%
class item:
    def __init__(self, name, width, height, depth, weight):
        self.name = name
        self.width = width
        self.height = height
        self.depth = depth
        self.weight = weight
        self.position = START_POSITION
        self.layer_position = 0
    
    def string(self):
        return "%s(%sx%sx%s, weight: %s) vol(%s)" % (
            self.name, self.width, self.height, self.depth, self.weight,
            self.get_volume()
        )
    
    def get_volume(self):
        return (self.width * self.height * self.depth)
    
    def get_base_volume(self):
        return (self.width * self.height)
    
    def get_dimension(self):
        return [self.width, self.height, self.depth]
    
    def get_name(self):
        return self.name
    
class Bin:
    def __init__(self, name, width, height, depth, max_weight):
        self.name = name
        self.width = width
        self.height = height
        self.depth = depth
        self.max_weight = max_weight
        self.items = []
        self.layers = []
        
    def string(self):
        return "%s(%sx%sx%s, max_weight:%s) vol(%s)" % (
            self.name, self.width, self.height, self.depth, self.max_weight,
            self.get_volume()
        )

    def get_volume(self):
        return self.width * self.height * self.depth
        
    def get_total_weight(self):
        total_weight = 0

        for item in self.items:
            total_weight += item.weight

        return total_weight

# %%
dataframe_veiculos = pd.read_excel('DadosParaDesafio-OtimizaçãoTransporte.xlsx', sheet_name='Veículos')



def extracao_veiculos(dataframe):
  lotacao = dataframe['Lotação (kg)'].tolist()	
  altura = dataframe['Altura'].tolist()	
  largura = dataframe['Largura'].tolist()	
  comprimento = dataframe['Comprimento'].tolist()	
  custo = dataframe['Custo / Km'].tolist()	
  tempo = dataframe['Tempo de trabalho (horas)'].tolist()
  for i in range(len(veiculos])):
    estrutura_veiculos = [[lotacao[i]] for _ in range(m)]

def extracao_caixas(dataframe):
